# %% [markdown]
# <a href="https://colab.research.google.com/github/Roy025/ML-Lab/blob/main/Class-Assignment/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import loadtxt
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout
import pandas as pd
import matplotlib.pyplot as plt
import csv
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Input Variables:
#
#
# ---
#
#
# 1. Number of times pregnant
#
# 2. Plasma glucose concentration at 2 hours in an oral glucose tolerance test
#
# 3. Diastolic blood pressure (mm Hg)
#
# 4. Triceps skin fold thickness (mm)
#
# 5. 2-hour serum insulin (mu U/ml)
#
# 6. Body mass index (weight in kg/(height in m)^2)
#
# 7. Diabetes pedigree function
#
# 8. Age (years)
#
#
# Output Variable:
#
#
# ---
#
# Class variable (0 or 1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = '/content/nn_data.txt'
dataset = pd.read_csv(data_path, header=None)
dataset.shape
print(dataset.head())
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
# split into input (X) and output (y) variables
# split into input (X) and output (y) variables
X = dataset.iloc[:,0:8]
y = dataset.iloc[:,8]

# %% [markdown]
# # Data Normalize(Scaling)

# %%
data = np.random.rand(100, 8) * 10

df = pd.DataFrame(data, columns=['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7'])

cols_to_be_scale = ['feature_0', 'feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7']

scaler = MinMaxScaler()

df[cols_to_be_scale] = scaler.fit_transform(df[cols_to_be_scale])

print(df.head())
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   0.537902   0.323100   0.951451   0.905748   0.785556   0.265730
# 1   0.254297   0.184743   0.707620   0.615685   0.777392   0.800565
# 2   0.757472   0.495309   0.516758   0.813796   0.143584   0.682847
# 3   0.365063   0.638492   0.133959   0.044694   0.677078   0.113220
# 4   0.198824   0.069017   0.788057   0.057192   0.624164   0.998928
#
#    feature_6  feature_7
# 0   0.917868   0.224876
# 1   0.049783   0.812222
# 2   0.011603   0.948072
# 3   0.760136   0.950399
# 4   0.488985   0.268756

# %%
X.head()
# Out:
#    0    1   2   3    4     5      6   7
# 0  6  148  72  35    0  33.6  0.627  50
# 1  1   85  66  29    0  26.6  0.351  31
# 2  8  183  64   0    0  23.3  0.672  32
# 3  1   89  66  23   94  28.1  0.167  21
# 4  0  137  40  35  168  43.1  2.288  33

# %%
# define the keras model
model = Sequential()
model.add(Dense(8, input_shape=(8,), activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 1ms/step - loss: 9.8461 - accuracy: 0.4596
# Epoch 2/100
# 77/77 [==============================] - 0s 1ms/step - loss: 3.7371 - accuracy: 0.5872
# Epoch 3/100
# 77/77 [==============================] - 0s 1ms/step - loss: 2.8389 - accuracy: 0.6250
# Epoch 4/100
# 77/77 [==============================] - 0s 1ms/step - loss: 2.2813 - accuracy: 0.6289
# Epoch 5/100
# 77/77 [==============================] - 0s 1ms/step - loss: 1.9625 - accuracy: 0.6354
# Epoch 6/100
# 77/77 [==============================] - 0s 1ms/step - loss: 1.7595 - accuracy: 0.6354
# Epoch 7/100
# 77/77 [==============================] - 0s 2ms/step - loss: 1.6140 - accuracy: 0.6380
# Epoch 8/100
# 77/77 [==============================] - 0s 2ms/step - loss: 1.4959 - accuracy: 0.6419
# Epoch 9/100
# 77/77 [==============================] - 0s 1ms/step - loss: 1.3630 - accuracy: 0.6523
# Epoch 10/100
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 976us/step - loss: 0.5186 - accuracy: 0.7565
# Accuracy: 75.65

# %%
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)
# summarize the first 5 cases
for i in range(5):
	print(' %d (expected %d)' % ( predictions[i], y[i]))
# Out:
# 24/24 [==============================] - 0s 998us/step
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
#  0 (expected 0)
#  1 (expected 1)
